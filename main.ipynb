# %% [markdown]
# # **GET MODEL**

# %%
# !python scripts/get_model.py --model_dir ./model
# Out:
# [+] Downloading model: byviz/bylastic_classification_logs
# [+] Saving model to: D:\Documents\UIT\Nam_4\NT505_KLTN\Cyberfortress-Src\Cyberfortress-ML-Logs-Classification\model_v2
# [✓] Model downloaded and saved successfully.
# 2025-12-04 16:00:08.987349: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-12-04 16:00:11.099513: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %% [markdown]
# # **INSPECT MODEL**

# %%
# !python scripts/inspect_model.py --model_dir ./model --output_res ./inspect
# Out:
# ================================================================================
# MODEL INSPECTION REPORT
# ================================================================================
# ================================================================================
# INSPECTION COMPLETED
# Results saved to: inspect
# ================================================================================

# %% [markdown]
# # **QUICK START MODEL**
#
# ```bash
# python quick_start.py --model_dir ./model --workers <num_workers>
# ```
#
# See `assets/eval_input/simple_ml_input.md` for input data.

# %% [markdown]
# # **PREPARE LOGS FOR MODEL**

# %%
# !python scripts/prepare_ml_ready.py assets/eval_logs/ecs_logs assets/eval_logs/processed_logs
# Out:
# ======================================================================
# BATCH LOG PROCESSOR
# ======================================================================
# Input:  d:\Documents\UIT\Nam_4\NT505_KLTN\Cyberfortress-Src\Cyberfortress-ML-Logs-Classification\assets\logs\ecs_logs
# Output: d:\Documents\UIT\Nam_4\NT505_KLTN\Cyberfortress-Src\Cyberfortress-ML-Logs-Classification\assets\logs\processed_logs
# Files:  9
# ======================================================================
#
# [1/9] modsecurity.json
#     [OK] 49 with ml_input, 0 skipped
# [2/9] mysql.json
#     [OK] 25 with ml_input, 0 skipped
# [3/9] nginx.json
#     [OK] 7 with ml_input, 60 skipped
# [4/9] pfsense.json
#     [OK] 500 with ml_input, 0 skipped
# [5/9] router.json
#     [OK] 0 with ml_input, 500 skipped
# [6/9] suricata.json
#     [OK] 500 with ml_input, 0 skipped
# [7/9] wazuh.json
#     [OK] 500 with ml_input, 0 skipped
# [8/9] windows.json
#     [OK] 500 with ml_input, 0 skipped
# [9/9] zeek.json
#     [OK] 0 with ml_input, 315 skipped
#
# ======================================================================
# SUMMARY
# ======================================================================
# Files:     9 total, 9 success, 0 failed
# Documents: 2956 total
# ML Input:  2081 (70.4%)
# Skipped:   875 (29.6%)
# Time:      0.8s (0.1s/file)
# ======================================================================
#
# Report: report_20251204_160624.json

# %% [markdown]
# # **EXTRACT LOGS FOR ML**

# %%
# !python scripts/extract_logs_for_ml.py assets/eval_logs/processed_logs assets/eval_input/eval_data.txt --simple-txt
# Out:
# ======================================================================
# ML INPUT EXTRACTOR
# ======================================================================
# Input directory: d:\Documents\UIT\Nam_4\NT505_KLTN\Cyberfortress-Src\Cyberfortress-ML-Logs-Classification\assets\logs\processed_logs
# Output file:     d:\Documents\UIT\Nam_4\NT505_KLTN\Cyberfortress-Src\Cyberfortress-ML-Logs-Classification\assets\input\eval_data.txt
# Found 9 files to process
# ======================================================================
#
# [1/9] Processing: modsecurity_ml_input.json
#     [OK] Extracted 49 ml_input entries
# [2/9] Processing: mysql_ml_input.json
#     [OK] Extracted 25 ml_input entries
# [3/9] Processing: nginx_ml_input.json
#     [OK] Extracted 7 ml_input entries
# [4/9] Processing: pfsense_ml_input.json
#     [OK] Extracted 500 ml_input entries
# [5/9] Processing: router_ml_input.json
#     [!] No ml_input fields found
# [6/9] Processing: suricata_ml_input.json
#     [OK] Extracted 500 ml_input entries
# [7/9] Processing: wazuh_ml_input.json
#     [OK] Extracted 500 ml_input entries
# [8/9] Processing: windows_ml_input.json
#     [OK] Extracted 500 ml_input entries
# [9/9] Processing: zeek_ml_input.json
#     [!] No ml_input fields found
#
# ======================================================================
# CONSOLIDATING DATA
# ======================================================================
# [OK] Saved TXT simple output: assets\input\eval_data.txt
# [OK] Successfully extracted 2081 ml_input entries

# %% [markdown]
# # **EVALUATE MODEL**

# %%
# !python scripts/evaluate_model.py assets/eval_input/eval_data.txt 12 assets/eval_results
# Out:
# ======================================================================
# ML MODEL EVALUATOR
# ======================================================================
# Input file:    d:\Documents\UIT\Nam_4\NT505_KLTN\Cyberfortress-Src\Cyberfortress-ML-Logs-Classification\assets\eval_input\eval_data.txt
# Model path:    d:\Documents\UIT\Nam_4\NT505_KLTN\Cyberfortress-Src\Cyberfortress-ML-Logs-Classification\model
# Output dir:    d:\Documents\UIT\Nam_4\NT505_KLTN\Cyberfortress-Src\Cyberfortress-ML-Logs-Classification\assets\eval_results
# CPU workers:   12
# Device:        CPU (multi-processing)
# ======================================================================
#
# Reading input file...
# [OK] Loaded 2081 log entries
#
# Starting evaluation with 12 workers...
# ======================================================================
# Progress: 100/2081 (4.8%) | Speed: 3.5 logs/s | ETA: 559.2s
# Progress: 200/2081 (9.6%) | Speed: 6.5 logs/s | ETA: 288.3s
# Progress: 300/2081 (14.4%) | Speed: 9.2 logs/s | ETA: 193.8s
# Progress: 400/2081 (19.2%) | Speed: 11.4 logs/s | ETA: 148.0s
# Progress: 500/2081 (24.0%) | Speed: 13.1 logs/s | ETA: 120.3s
# Progress: 600/2081 (28.8%) | Speed: 14.3 logs/s | ETA: 103.9s
# Progress: 700/2081 (33.6%) | Speed: 15.8 logs/s | ETA: 87.6s
# Progress: 800/2081 (38.4%) | Speed: 16.5 logs/s | ETA: 77.6s
# Progress: 900/2081 (43.2%) | Speed: 17.1 logs/s | ETA: 69.0s
# Progress: 1000/2081 (48.1%) | Speed: 17.7 logs/s | ETA: 61.1s
# Progress: 1100/2081 (52.9%) | Speed: 16.8 logs/s | ETA: 58.4s
# Progress: 1200/2081 (57.7%) | Speed: 16.4 logs/s | ETA: 53.8s
# Progress: 1300/2081 (62.5%) | Speed: 16.4 logs/s | ETA: 47.5s
# Progress: 1400/2081 (67.3%) | Speed: 15.8 logs/s | ETA: 43.1s
# Progress: 1500/2081 (72.1%) | Speed: 15.5 logs/s | ETA: 37.5s
# Progress: 1600/2081 (76.9%) | Speed: 14.4 logs/s | ETA: 33.4s
# Progress: 1700/2081 (81.7%) | Speed: 13.4 logs/s | ETA: 28.5s
# Progress: 1800/2081 (86.5%) | Speed: 13.3 logs/s | ETA: 21.1s
# Progress: 1900/2081 (91.3%) | Speed: 13.3 logs/s | ETA: 13.6s
# Progress: 2000/2081 (96.1%) | Speed: 13.1 logs/s | ETA: 6.2s
# Progress: 2081/2081 (100.0%) | Speed: 13.2 logs/s | ETA: 0.0s
# ======================================================================
#
# Saving results...
# [OK] JSON results saved to: assets\eval_results\eval_eval_data_20251204_162317.json
# [OK] TXT summary saved to: assets\eval_results\eval_eval_data_20251204_162317.txt
#
# ======================================================================
# EVALUATION SUMMARY
# ======================================================================
# Total logs:    2081
# Successful:    2081 (100.0%)
# Failed:        0 (0.0%)
# Total time:    158.38 seconds
# Throughput:    13.14 logs/second
#
# Avg latency:   774.86 ms
# P95 latency:   1779.44 ms
# P99 latency:   2495.78 ms
#
# Prediction distribution:
#   ERROR           0 (  0.0%)
#   WARNING      2062 ( 99.1%)
#   INFO           19 (  0.9%)
#
# Class distribution:
#   Class 1 (WARNING):   2062 ( 99.1%)
#   Class 2 (INFO   ):     19 (  0.9%)
# ======================================================================
#
# [OK] Evaluation completed successfully!

# %% [markdown]
# # **VISUALIZE RESULTS**

# %%
# !python scripts/visualize_results.py --input assets/eval_results/eval_eval_data_20251204_162317.json --output assets/eval_charts
# Out:
# [+] Generating visualization...
# [✓] Visualization completed. Files saved to: assets/eval_charts
